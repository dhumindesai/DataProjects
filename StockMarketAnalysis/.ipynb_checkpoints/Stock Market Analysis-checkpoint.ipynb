# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from pandas.io.data import DataReader

from datetime import datetime

from __future__ import division
# Out:
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/pandas/io/data.py:35: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)

# %%
endtime = datetime.now()
starttime = datetime(endtime.year - 1, endtime.month, endtime.day)
stocks = ['AAPL','GOOG','AMZN','MSFT','NKE']

# %%
for stock in stocks:
    globals()[stock] = DataReader(stock,'yahoo',starttime,endtime)

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   108.968056  109.844246  108.308294  109.155159  3.466248e+07
# std     10.421893   10.417556   10.512287   10.518052  1.528902e+07
# min     90.000000   91.669998   89.470001   90.339996  1.147590e+07
# 25%     99.957501  100.972500   99.564998  100.500000  2.588480e+07
# 50%    108.774998  109.730000  108.115002  108.919998  3.051420e+07
# 75%    115.137503  116.184999  114.055000  115.574999  3.765552e+07
# max    137.380005  137.479996  136.699997  137.110001  1.146021e+08
#
#         Adj Close
# count  252.000000
# mean   108.003352
# std     10.934169
# min     89.008370
# 25%     98.819171
# 50%    107.556231
# 75%    114.692743
# max    137.110001

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2016-03-01 to 2017-02-28
# Data columns (total 6 columns):
# Open         252 non-null float64
# High         252 non-null float64
# Low          252 non-null float64
# Close        252 non-null float64
# Volume       252 non-null int64
# Adj Close    252 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
AAPL['Adj Close'].plot(legend = True, figsize = (15,7))

# %%
AAPL['Volume'].plot(legend = True, figsize = (15,7))

# %%
pd.rolling_mean(AAPL['Adj Close'],20).plot()
pd.rolling_mean(AMZN['Adj Close'],20).plot()
# Out:
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
#   if __name__ == '__main__':
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
#   from ipykernel import kernelapp as app

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

def add_norm_column(stock):
    x = stock['Adj Close']
    x_scaled = pd.Series(scaler.fit_transform(x), index = stock.index)
    stock['Normalized Adj Close'] = x_scaled

# %%
add_norm_column(AAPL)
add_norm_column(AMZN)
add_norm_column(GOOG)
add_norm_column(MSFT)
add_norm_column(NKE)
# Out:
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
pd.rolling_mean(AAPL['Normalized Adj Close'],50).plot()
pd.rolling_mean(AMZN['Normalized Adj Close'],50).plot()
pd.rolling_mean(GOOG['Normalized Adj Close'],50).plot()
pd.rolling_mean(MSFT['Normalized Adj Close'],50).plot()
pd.rolling_mean(NKE['Normalized Adj Close'],50).plot()
# Out:
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()
#   if __name__ == '__main__':
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()
#   from ipykernel import kernelapp as app
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()
#   app.launch_new_instance()
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()

# %%
np.corrcoef(AAPL['Normalized Adj Close'],NKE['Normalized Adj Close'])
# Out:
# array([[ 1.        , -0.29861235],
#        [-0.29861235,  1.        ]])

# %%
mas = [10,20,50]

for stock in [AAPL,GOOG,AMZN,MSFT,NKE]:
    for ma in mas:
        column_name = 'MA for %s days'%str(ma)
        stock[column_name] = pd.rolling_mean(stock['Adj Close'],ma)
# Out:
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=50,center=False).mean()

# %%
AAPL[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize = (15,7))

# %%
GOOG[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize = (15,7))

# %%
AMZN[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize = (15,7))

# %%
MSFT[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize = (15,7))

# %%
NKE[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize = (15,7))

# %%
AAPL['Daily Returns'] = AAPL['Adj Close'].pct_change()

# %%
AAPL['Daily Returns'].plot(figsize = (15,7), marker = 'o')

# %%
plt.figure(figsize=(15,7))
sns.distplot(AAPL['Daily Returns'].dropna())

# %%
closing_df = DataReader(['GOOG','AAPL','AMZN','MSFT','NKE'],'yahoo',starttime,endtime)['Adj Close']
closing_df.head()
# Out:
#                   AAPL        AMZN        GOOG       MSFT        NKE
# Date
# 2016-03-01   98.448766  579.039978  718.809998  51.232568  62.177363
# 2016-03-02   98.664213  580.210022  718.849976  51.593085  61.485628
# 2016-03-03   99.398686  577.489990  712.419983  51.008458  60.901090
# 2016-03-04  100.877427  575.140015  710.890015  50.696659  60.693030
# 2016-03-07   99.761029  562.799988  695.159973  49.722286  58.701635

# %%
rets = closing_df.pct_change()
rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT       NKE
# Date
# 2016-03-01       NaN       NaN       NaN       NaN       NaN
# 2016-03-02  0.002188  0.002021  0.000056  0.007037 -0.011125
# 2016-03-03  0.007444 -0.004688 -0.008945 -0.011331 -0.009507
# 2016-03-04  0.014877 -0.004069 -0.002148 -0.006113 -0.003416
# 2016-03-07 -0.011067 -0.021456 -0.022127 -0.019220 -0.032811

# %%
sns.jointplot('GOOG','MSFT',rets,kind='scatter')

# %%
from IPython.display import SVG
SVG(url='http://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg')

# %%
sns.pairplot(rets.dropna())

# %%
ret_fig = sns.PairGrid(rets.dropna())
ret_fig.map_lower(plt.scatter)
ret_fig.map_upper(sns.kdeplot)
ret_fig.map_diag(plt.hist)

# %%
ret_fig = sns.PairGrid(closing_df.dropna())
ret_fig.map_lower(plt.scatter)
ret_fig.map_upper(sns.kdeplot)
ret_fig.map_diag(plt.hist)

# %%
np.corrcoef(closing_df.AMZN,closing_df.GOOG)
# Out:
# array([[ 1.        ,  0.70176651],
#        [ 0.70176651,  1.        ]])

# %%
np.corrcoef(closing_df.NKE,closing_df.AAPL)
# Out:
# array([[ 1.        , -0.29861235],
#        [-0.29861235,  1.        ]])

# %%
rets.dropna(inplace=True)

# %% [markdown]
# # Risk Analysis
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
plt.scatter(rets.mean(),rets.std(),s=np.pi*20)
plt.xlim([-0.001,0.003])
plt.ylim([0.01,0.015])
plt.xlabel('Expected Returns')
plt.ylabel('Risk')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,angleA=-90,angleB=0,armA=0,rad=0'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-4acd4317c541> in <module>()
#       9         xy = (x, y), xytext = (50, 50),
#      10         textcoords = 'offset points', ha = 'right', va = 'bottom',
# ---> 11         arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,angleA=-90,angleB=0,armA=0,rad=0'))
#
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in annotate(*args, **kwargs)
#    3572 @docstring.copy_dedent(Axes.annotate)
#    3573 def annotate(*args, **kwargs):
# -> 3574     ret = gca().annotate(*args, **kwargs)
#    3575     return ret
#    3576
#
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in annotate(self, *args, **kwargs)
#     672         .. plot:: mpl_examples/pylab_examples/annotation_demo2.py
#     673         """
# --> 674         a = mtext.Annotation(*args, **kwargs)
#     675         a.set_transform(mtransforms.IdentityTransform())
#     676         if 'clip_on' in kwargs:
#
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/matplotlib/text.pyc in __init__(self, s, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2077                         arrowprops[key] = val  # basic Patch properties
#    2078             self.arrow_patch = FancyArrowPatch((0, 0), (1, 1),
# -> 2079                                                **arrowprops)
#    2080         else:
#    2081             self.arrow_patch = None
#
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in __init__(self, posA, posB, path, arrowstyle, arrow_transmuter, connectionstyle, connector, patchA, patchB, shrinkA, shrinkB, mutation_scale, mutation_aspect, dpi_cor, **kwargs)
#    4006             if connectionstyle is None:
#    4007                 connectionstyle = "arc3"
# -> 4008             self.set_connectionstyle(connectionstyle)
#    4009
#    4010         elif posA is None and posB is None and path is not None:
#
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in set_connectionstyle(self, connectionstyle, **kw)
#    4094             self._connector = connectionstyle
#    4095         else:
# -> 4096             self._connector = ConnectionStyle(connectionstyle, **kw)
#    4097         self.stale = True
#    4098
#
# /Users/dhrumindesai/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in __new__(self, stylename, **kw)
#    1833         _args.update(kw)
#    1834
# -> 1835         return _cls(**_args)
#    1836
#    1837     @classmethod
#
# TypeError: __init__() got an unexpected keyword argument 'armA'
